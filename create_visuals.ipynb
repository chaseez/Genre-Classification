# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
categories = ['Baseline', 'MLP', 'Random Forest', 'KNN', 'XGB']
values = [10, 62.5, 65.8, 62.9, 59.8]

# Create bar graph
sns.barplot(x=categories, y=values)

# Add labels and title
plt.xlabel('Models')
plt.ylabel('Accuracy %')
plt.title('Initial Results')

# Create a legend
# legend_labels = ['Baseline', 'Category B', 'Category C', 'Category D']
# plt.legend(loc='upper right')

# Show the plot
plt.show()
# Out:
# /Users/chasezundel/opt/anaconda3/envs/ML/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
